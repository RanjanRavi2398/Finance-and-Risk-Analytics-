# %% [markdown]
# #1.**Introduction**

# %% [markdown]
# 1.1 **Problem Statement :**
#
#   In the recent past, the industry of wealth management has seen a lot of growth. Individuals and businesses actively seek maximum returns. However, in many cases, they lack either the skills to identify the right investment opportunities or the time to find such opportunities. This challenge gave rise to the dedicated individuals who perform this task on behalf of the investors for a commission: portfolio managers.
#
#   A portfolio manager makes investment decisions and carries out other related activities on behalf of vested investors. They work with a team of analysts and researchers, and their main objective is to realize the needs of the investor and suggest a suitable portfolio that meets all the expectations. They are responsible for establishing the best investment strategy and selecting appropriate investments with the right allocations. However, in doing so, they face a lot of competition in the form of other portfolio managers and rival firms. Therefore, the portfolio manager has to use the available resources to provide the best solution to the investor.
#
#   Consider yourself working for an associate at an investment firm that manages accounts for private clients. Your role requires you to analyze a portfolio of stocks to provide consultation on investment management based on client requirements.

# %% [markdown]
# **1.2 Business Goal**
#
#
# As a portfolio manager our task is to provide consultation to two different investors, Mr Patrick Jyenger and Mr Peter Jyenger based on their requirements and financial objectives
#
# Goal of the Case Study is :
#
# 1.   To Suggest a Portfolio of stocks to Mr Patrick Jyenger based on his risk profile to meet his goal on doubling the amount of 500K Dollars in five years of timespan to buy a minoruty stake in Naturo.
# 2.  To Suggest a High risk stocks to Mr Peter Jyenger based on his risk profile to meet his goal on gaining higher returns for the invested amount of 1 Million Dollars over a five years of timespan to use it for the expansion of JWW.

# %% [markdown]
# 1.3 Data Dictionary :
#
#
# *   Date:stock ranges from 1st October 2010 to 30th September 2020
#
# *   Open price: Price of stock at the start of the day
#
# *   Close price: Price of stock at the end of the day
# *   High price: Highest price reached by the stock on that day
#
#
# *  Low price: Lowest price reached by the stock on that day
#
#
# *   Adjusted close price: Stock price adjusted to include the annual returns (dividends) that the company offers to the shareholders
#
# *   Volume traded: Number of stocks traded on the day

# %% [markdown]
# **Connected to gdrive for dataset**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ##2.**Python Libraries:**

# %%
# !pip3 install chart_studio
# Out:
# Collecting chart_studio
#   Using cached chart_studio-1.1.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: plotly in c:\users\raviy\anaconda3\lib\site-packages (from chart_studio) (5.9.0)
# Requirement already satisfied: requests in c:\users\raviy\anaconda3\lib\site-packages (from chart_studio) (2.28.1)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in c:\users\raviy\anaconda3\lib\site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\raviy\anaconda3\lib\site-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raviy\anaconda3\lib\site-packages (from requests->chart_studio) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\raviy\anaconda3\lib\site-packages (from requests->chart_studio) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\raviy\anaconda3\lib\site-packages (from requests->chart_studio) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raviy\anaconda3\lib\site-packages (from requests->chart_studio) (3.3)
# Installing collected packages: retrying, chart_studio
# Successfully installed chart_studio-1.1.0 retrying-1.3.4

# %%
# !pip3 install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.730-py3-none-any.whl (67 kB)
#      ---------------------------------------- 67.0/67.0 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (4.3.0)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (2022.7.1)
# Requirement already satisfied: statsmodels in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: ipython in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (7.31.1)
# Requirement already satisfied: xlrd in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (2.0.1)
# Collecting emoji
#   Downloading emoji-2.7.0.tar.gz (361 kB)
#      -------------------------------------- 361.8/361.8 kB 5.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: seaborn>=0.11.1 in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (0.11.2)
# Collecting hvplot~=0.7.3
#   Downloading hvplot-0.7.3-py2.py3-none-any.whl (3.1 MB)
#      ---------------------------------------- 3.1/3.1 MB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (1.0.2)
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp39-cp39-win_amd64.whl (153 kB)
#      ---------------------------------------- 153.3/153.3 kB ? eta 0:00:00
# Requirement already satisfied: numpy in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (1.21.5)
# Requirement already satisfied: pandas in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (1.4.4)
# Requirement already satisfied: nltk in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (3.7)
# Collecting pandas-dq==1.28
#   Downloading pandas_dq-1.28-py3-none-any.whl (25 kB)
# Collecting pyamg
#   Downloading pyamg-5.0.1-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 16.4 MB/s eta 0:00:00
# Collecting xgboost>=0.82
#   Downloading xgboost-1.7.6-py3-none-win_amd64.whl (70.9 MB)
#      --------------------------------------- 70.9/70.9 MB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: panel>=0.12.6 in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (0.13.1)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ------------------------------------- 636.8/636.8 kB 20.2 MB/s eta 0:00:00
# Collecting holoviews~=1.14.9
#   Downloading holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (3.5.2)
# Requirement already satisfied: bokeh~=2.4.2 in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (2.4.3)
# Requirement already satisfied: jupyter in c:\users\raviy\anaconda3\lib\site-packages (from autoviz) (1.0.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\raviy\anaconda3\lib\site-packages (from bokeh~=2.4.2->autoviz) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\raviy\anaconda3\lib\site-packages (from bokeh~=2.4.2->autoviz) (2.11.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\raviy\anaconda3\lib\site-packages (from bokeh~=2.4.2->autoviz) (21.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\raviy\anaconda3\lib\site-packages (from bokeh~=2.4.2->autoviz) (6.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\raviy\anaconda3\lib\site-packages (from bokeh~=2.4.2->autoviz) (9.2.0)
# Requirement already satisfied: colorcet in c:\users\raviy\anaconda3\lib\site-packages (from holoviews~=1.14.9->autoviz) (3.0.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\raviy\anaconda3\lib\site-packages (from holoviews~=1.14.9->autoviz) (2.0.2)
# Requirement already satisfied: param<2.0,>=1.9.3 in c:\users\raviy\anaconda3\lib\site-packages (from holoviews~=1.14.9->autoviz) (1.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\raviy\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raviy\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raviy\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\raviy\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\raviy\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raviy\anaconda3\lib\site-packages (from pandas->autoviz) (2022.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\raviy\anaconda3\lib\site-packages (from panel>=0.12.6->autoviz) (0.4.8)
# Requirement already satisfied: markdown in c:\users\raviy\anaconda3\lib\site-packages (from panel>=0.12.6->autoviz) (3.3.4)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\raviy\anaconda3\lib\site-packages (from panel>=0.12.6->autoviz) (4.64.1)
# Requirement already satisfied: setuptools in c:\users\raviy\anaconda3\lib\site-packages (from panel>=0.12.6->autoviz) (63.4.1)
# Requirement already satisfied: bleach in c:\users\raviy\anaconda3\lib\site-packages (from panel>=0.12.6->autoviz) (4.1.0)
# Requirement already satisfied: requests in c:\users\raviy\anaconda3\lib\site-packages (from panel>=0.12.6->autoviz) (2.28.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\raviy\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\raviy\anaconda3\lib\site-packages (from scikit-learn->autoviz) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\raviy\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.9.1)
# Requirement already satisfied: pygments in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (2.11.2)
# Requirement already satisfied: decorator in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (0.1.6)
# Requirement already satisfied: colorama in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (0.4.5)
# Requirement already satisfied: backcall in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\raviy\anaconda3\lib\site-packages (from ipython->autoviz) (0.18.1)
# Requirement already satisfied: jupyter-console in c:\users\raviy\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.3)
# Requirement already satisfied: ipykernel in c:\users\raviy\anaconda3\lib\site-packages (from jupyter->autoviz) (6.15.2)
# Requirement already satisfied: qtconsole in c:\users\raviy\anaconda3\lib\site-packages (from jupyter->autoviz) (5.2.2)
# Requirement already satisfied: ipywidgets in c:\users\raviy\anaconda3\lib\site-packages (from jupyter->autoviz) (7.6.5)
# Requirement already satisfied: notebook in c:\users\raviy\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.12)
# Requirement already satisfied: nbconvert in c:\users\raviy\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\raviy\anaconda3\lib\site-packages (from nltk->autoviz) (2022.7.9)
# Requirement already satisfied: click in c:\users\raviy\anaconda3\lib\site-packages (from nltk->autoviz) (8.0.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\raviy\anaconda3\lib\site-packages (from statsmodels->autoviz) (0.5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\raviy\anaconda3\lib\site-packages (from jedi>=0.16->ipython->autoviz) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\raviy\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh~=2.4.2->autoviz) (2.0.1)
# Requirement already satisfied: six in c:\users\raviy\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\raviy\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Requirement already satisfied: webencodings in c:\users\raviy\anaconda3\lib\site-packages (from bleach->panel>=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: psutil in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (5.9.0)
# Requirement already satisfied: nest-asyncio in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (23.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (5.5.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (1.0.0)
# Requirement already satisfied: testpath in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.4)
# Requirement already satisfied: jupyter-core in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\raviy\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\raviy\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\raviy\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\raviy\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (0.14.1)
# Requirement already satisfied: qtpy in c:\users\raviy\anaconda3\lib\site-packages (from qtconsole->jupyter->autoviz) (2.2.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\raviy\anaconda3\lib\site-packages (from requests->panel>=0.12.6->autoviz) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raviy\anaconda3\lib\site-packages (from requests->panel>=0.12.6->autoviz) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raviy\anaconda3\lib\site-packages (from requests->panel>=0.12.6->autoviz) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\raviy\anaconda3\lib\site-packages (from requests->panel>=0.12.6->autoviz) (1.26.11)
# Requirement already satisfied: pywin32>=1.0 in c:\users\raviy\anaconda3\lib\site-packages (from jupyter-core->nbconvert->jupyter->autoviz) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\raviy\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\raviy\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (2.16.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\raviy\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->autoviz) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\raviy\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\raviy\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz) (2.3.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\raviy\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\raviy\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\raviy\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\raviy\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (2.21)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (pyproject.toml): started
#   Building wheel for emoji (pyproject.toml): finished with status 'done'
#   Created wheel for emoji: filename=emoji-2.7.0-py2.py3-none-any.whl size=356589 sha256=d9ab9748d1020ebab7dd3f11dba6fce12773606e6498369618667cd29c760ccb
#   Stored in directory: c:\users\raviy\appdata\local\pip\cache\wheels\46\6f\a1\87ad867ec0c6b1e2ac8e5ff8535e492697927a7b72f12228be
# Successfully built emoji
# Installing collected packages: emoji, xgboost, pyamg, wordcloud, textblob, pandas-dq, holoviews, hvplot, autoviz
#   Attempting uninstall: holoviews
#     Found existing installation: holoviews 1.15.0
#     Uninstalling holoviews-1.15.0:
#       Successfully uninstalled holoviews-1.15.0
#   Attempting uninstall: hvplot
#     Found existing installation: hvplot 0.8.0
#     Uninstalling hvplot-0.8.0:
#       Successfully uninstalled hvplot-0.8.0
# Successfully installed autoviz-0.1.730 emoji-2.7.0 holoviews-1.14.9 hvplot-0.7.3 pandas-dq-1.28 pyamg-5.0.1 textblob-0.17.1 wordcloud-1.9.2 xgboost-1.7.6

# %%
# !pip3 install cufflinks
# Out:
# Collecting cufflinks
#   Using cached cufflinks-0.17.3.tar.gz (81 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in c:\users\raviy\anaconda3\lib\site-packages (from cufflinks) (1.21.5)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\raviy\anaconda3\lib\site-packages (from cufflinks) (1.4.4)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\raviy\anaconda3\lib\site-packages (from cufflinks) (5.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\raviy\anaconda3\lib\site-packages (from cufflinks) (1.16.0)
# Collecting colorlover>=0.2.1
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\raviy\anaconda3\lib\site-packages (from cufflinks) (63.4.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\raviy\anaconda3\lib\site-packages (from cufflinks) (7.31.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\raviy\anaconda3\lib\site-packages (from cufflinks) (7.6.5)
# Requirement already satisfied: backcall in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: decorator in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: pygments in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.20)
# Requirement already satisfied: colorama in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\raviy\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.18.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (6.15.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\raviy\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raviy\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\raviy\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.0.1)
# Requirement already satisfied: packaging in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (21.3)
# Requirement already satisfied: psutil in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\raviy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\raviy\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: fastjsonschema in c:\users\raviy\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\raviy\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.16.0)
# Requirement already satisfied: jupyter_core in c:\users\raviy\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.11.1)
# Requirement already satisfied: wcwidth in c:\users\raviy\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\raviy\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.4.12)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\raviy\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\raviy\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\raviy\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\raviy\anaconda3\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (302)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\raviy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.13.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\raviy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.4.4)
# Requirement already satisfied: jinja2 in c:\users\raviy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\raviy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\raviy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\raviy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.14.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\raviy\anaconda3\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.0.9)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.11.1)
# Requirement already satisfied: testpath in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: bleach in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\raviy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\raviy\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.0.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\raviy\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\raviy\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\raviy\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\raviy\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\raviy\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\raviy\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.21)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68718 sha256=a68809f6c1ae34a022ef4437ec128666ec7b9c94456b14d1d3f2981793b4b73b
#   Stored in directory: c:\users\raviy\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# Installing collected packages: colorlover, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3

# %%
#Data Analysis & Data wrangling Libraries
import numpy as np
import pandas as pd
from collections import Counter
from functools import reduce
from datetime import datetime
from scipy import stats
import autoviz

# Standard plotly imports
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode

# Using plotly + cufflinks in offline mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)

#Visualization Librarues
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
# %matplotlib inline

# Plot Style
sns.set_context("paper")
style.use('fivethirtyeight')
#image display library
from IPython import display



#Sci-kit learn libraries

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error


#statsmodel libraries
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from pylab import rcParams
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# **2.2 Suppress Warnings:**

# %%
# Supress the Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **2.3 Setting up Jupyter View**

# %%
# We can see the max rows & columns with the help of below code
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# **3 Reading & Understanding the data**

# %% [markdown]
# **3.1 Importing the Input file**

# %%
#Let import the datasets of all stocks
av_path='Aviation/'
## AVIATION STOCKS
American_Airlines = pd.read_csv(av_path+"AAL.csv")
Allegiant_Travel = pd.read_csv(av_path+"ALGT.csv")
Alaska_Air = pd.read_csv(av_path+"ALK.csv")
Delta_AirLines = pd.read_csv(av_path+"DAL.csv")
Hawaiian_Holdings = pd.read_csv(av_path+"HA.csv")
Southwest_Airlines = pd.read_csv(av_path+"LUV.csv")
##Finance path
fi_path='Finance/'
## FINANCE STOCKS
Barclays = pd.read_csv(fi_path+"BCS.csv")
Credit_Suisse = pd.read_csv(fi_path+"CS.csv")
Deutsche_Bank = pd.read_csv(fi_path+"DB.csv")
Goldman_Sachs = pd.read_csv(fi_path+"GS.csv")
Morgan_Stanley = pd.read_csv(fi_path+"MS.csv")
Wells_Fargo = pd.read_csv(fi_path+"WFC.csv")
##HealthCare Path
he_path='pharma_Healthcare/'
## HEALTHCARE STOCKS
Johnson_and_Johnson = pd.read_csv(he_path+"JNJ.csv")
Merck_and_CO = pd.read_csv(he_path+"MRK.csv")
Pfizer = pd.read_csv(he_path+"PFE.csv")
UnitedHealthGroup = pd.read_csv(he_path+"UNH.csv")

## PHARMACEUTICAL STOCKS
Bausch_Health = pd.read_csv(he_path+"BHC.csv")
Roche_Holding = pd.read_csv(he_path+"RHHBY.csv")
##Technology Path
te_path='Technology/'

## TECHNOLOGY STOCKS
Apple = pd.read_csv(te_path+"AAPL.csv")
Amazon = pd.read_csv(te_path+"AMZN.csv")
Facebook = pd.read_csv(te_path+"FB.csv")
Alphabet = pd.read_csv(te_path+"GOOG.csv")
IBM = pd.read_csv(te_path+"IBM.csv")
Microsoft = pd.read_csv(te_path+"MSFT.csv")

#s&p500 Index
normal_path=''
SP500 = pd.read_csv(normal_path+"S&P500.csv")
Annexure=pd.read_csv(normal_path+"Annexure-I.csv")

# %%
Annexure
# Out:
#    Ticker     Industry             Company Name
# 0     AAL         Aviation  American Airlines Group Inc
# 1    ALGT         Aviation     Allegiant Travel Company
# 2     ALK         Aviation         Alaska Air Group Inc
# 3     DAL         Aviation          Delta Air Lines Inc
# 4      HA         Aviation        Hawaiian Holdings Inc
# 5     LUV         Aviation        Southwest Airlines Co
# 6     BCS          Finance                     Barclays
# 7      CS          Finance                Credit Suisse
# 8      DB          Finance                Deutsche Bank
# 9      GS          Finance                Goldman Sachs
# 10     MS          Finance               Morgan Stanley
# 11    WFC          Finance                 Wells Fargo
# 12    JNJ       Healthcare            Johnson & Johnson
# 13    MRK       Healthcare            Merck and CO inc.
# 14    PFE       Healthcare                   Pfizer inc
# 15   UNH        Healthcare        UnitedHealthGroup Inc
# 16    BHC  Pharmaceuticals  Bausch Health Companies inc
# 17  RHHBY  Pharmaceuticals             Roche Holding AG
# 18   AAPL       Technology                    Apple Inc
# 19   AMZN       Technology                       Amazon
# 20     FB       Technology                     Facebook
# 21   GOOG       Technology                     Alphabet
# 22    IBM       Technology                          IBM
# 23   MSFT       Technology                    Microsoft

# %%
def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  _, ax = plt.subplots(figsize=figsize)
  bars = df[colname].value_counts()
  plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
  plt.title(colname)
  ax.spines[['top', 'right',]].set_visible(False)
  return autoviz

# %%
##Distribution of different sector in Annexure
chart = categorical_histogram(Annexure, *['Industry'], **{})
chart
# Out:
# <module 'autoviz' from 'C:\\Users\\raviy\\anaconda3\\lib\\site-packages\\autoviz\\__init__.py'>

# %%
#display first 10 records of the dataframe ad
American_Airlines.head(10)
# Out:
#       Date     Open  High   Low  Close  Adj Close   Volume
# 0  01-10-2010  9.29  9.39  9.21  9.29   8.758067    3603800
# 1  04-10-2010  9.24  9.48  9.05  9.12   8.597802    3856800
# 2  05-10-2010  9.27  9.35  9.15  9.23   8.701504    3896600
# 3  06-10-2010  9.27  9.40  9.15  9.23   8.701504    3230200
# 4  07-10-2010  9.30  9.31  9.07  9.24   8.710930    3877700
# 5  08-10-2010  9.22  9.26  9.00  9.07   8.550665    4455700
# 6  11-10-2010  9.06  9.16  9.00  9.00   8.484673    2231500
# 7  12-10-2010  9.02  9.57  8.94  9.55   9.003184   10884900
# 8  13-10-2010  9.67  9.90  9.65  9.80   9.238865    7754800
# 9  14-10-2010  9.76  9.81  9.62  9.78   9.220010    3760500

# %%
def histogram(df, colname, num_bins=20, figsize=(5, 3)):
  from matplotlib import pyplot as plt
  for i in range(0,len(colname)):
      _, ax = plt.subplots(figsize=figsize)
      plt.hist(df[colname[i]], bins=num_bins, histtype='stepfilled')
      plt.ylabel('count')
      plt.title(colname[i])
      ax.spines[['top', 'right',]].set_visible(False)
      plt.tight_layout()
  return autoviz

# %%
def value_plot(df, y, sort_ascending=False, figsize=(5, 3)):
  from matplotlib import pyplot as plt
  for i in range(0,len(y)):
      if sort_ascending:
        df = df.sort_values(y[i]).reset_index(drop=True)
      _, ax = plt.subplots(figsize=figsize)
      df[y[i]].plot(kind='line')
      plt.title(y[i])
      ax.spines[['top', 'right',]].set_visible(False)
      plt.tight_layout()
  return autoviz

# %%
def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(5, 3), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette(mpl_palette_name))
  def _plot_series(series, series_name, series_index=0):
    for i in range(0,len(value_colname)):
        if value_colname[i] == 'count()':
          counted = (series[timelike_colname]
                    .value_counts()
                    .reset_index(name='counts')
                    .rename({'index': timelike_colname}, axis=1)
                    .sort_values(timelike_colname, ascending=True))
          xs = counted[timelike_colname]
          ys = counted['counts']
        else:
          xs = series[timelike_colname]
          ys = series[value_colname[i]]
        plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

        fig, ax = plt.subplots(figsize=figsize, layout='constrained')
        df = df.sort_values(timelike_colname, ascending=True)
        if series_colname:
          for i, (series_name, series) in enumerate(df.groupby(series_colname)):
            _plot_series(series, series_name, i)
          fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
        else:
          _plot_series(df, '')
        sns.despine(fig=fig, ax=ax)
        plt.xlabel(timelike_colname)
        plt.ylabel(value_colname[i])
  return autoviz

# %%
def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
  from matplotlib import pyplot as plt
  plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
  for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
    ax = plt.subplot(1, len(colname_pairs), plot_i)
    ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
    plt.xlabel(x_colname)
    plt.ylabel(y_colname)
    ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz

# %%
Aviation_col=['High','Low','Close','Open','Adj Close','Volume']

# %%
chart = histogram(American_Airlines, Aviation_col, **{})
chart
# Out:
# <module 'autoviz' from 'C:\\Users\\raviy\\anaconda3\\lib\\site-packages\\autoviz\\__init__.py'>

# %%
chart = value_plot(American_Airlines, Aviation_col, **{})
chart
# Out:
# <module 'autoviz' from 'C:\\Users\\raviy\\anaconda3\\lib\\site-packages\\autoviz\\__init__.py'>

# %%
#Renaming the columns in the dataset and changing the close column to the stock name for easy reference

American_Airlines = American_Airlines.rename(columns = {'Open': 'AAL_Open', 'High': 'AAL_High','Low': 'AAL_Low','Close': 'AAL','Adj Close': 'AAL_Adj Close','Volume': 'AAL_Volume'}, inplace = False)
Allegiant_Travel = Allegiant_Travel.rename(columns = {'Open': 'ALGT_Open', 'High': 'ALGT_High','Low': 'ALGT_Low','Close': 'ALGT','Adj Close': 'ALGT_Adj Close','Volume': 'ALGT_Volume'}, inplace = False)
Alaska_AirLk = Alaska_Air.rename(columns = {'Open': 'ALK_Open', 'High': 'ALK_High','Low': 'ALK_Low','Close': 'ALK','Adj Close': 'ALK_Adj Close','Volume': 'ALK_Volume'}, inplace = False)
Delta_AirLines = Delta_AirLines.rename(columns = {'Open': 'DAL_Open', 'High': 'DAL_High','Low': 'DAL_Low','Close': 'DAL','Adj Close': 'DAL_Adj Close','Volume': 'DAL_Volume'}, inplace = False)
Hawaiian_Holdings = Hawaiian_Holdings.rename(columns = {'Open': 'HA_Open', 'High': 'HA_High','Low': 'HA_Low','Close': 'HA','Adj Close': 'HAL_Adj Close','Volume': 'HAL_Volume'}, inplace = False)
Southwest_Airlines = Southwest_Airlines.rename(columns = {'Open': 'LUV_Open', 'High': 'LUV_High','Low': 'LUV_Low','Close': 'LUV','Adj Close': 'LUV_Adj Close','Volume': 'LUV_Volume'}, inplace = False)

Barclays = Barclays.rename(columns = {'Open': 'BCS_Open', 'High': 'BCS_High','Low': 'BCS_Low','Close': 'BCS','Adj Close': 'BCS_Adj Close','Volume': 'BCS_Volume'}, inplace = False)
Credit_Suisse = Credit_Suisse.rename(columns = {'Open': 'CS_Open', 'High': 'CS_High','Low': 'CS_Low','Close': 'CS','Adj Close': 'CS_Adj Close','Volume': 'CS_Volume'}, inplace = False)
Deutsche_Bank= Deutsche_Bank.rename(columns = {'Open': 'DB_Open', 'High': 'DB_High','Low': 'DB_Low','Close': 'DB','Adj Close': 'DB_Adj Close','Volume': 'DB_Volume'}, inplace = False)
Goldman_Sachs = Goldman_Sachs.rename(columns = {'Open': 'GS_Open', 'High': 'GS_High','Low': 'GS_Low','Close': 'GS','Adj Close': 'GS_Adj Close','Volume': 'GS_Volume'}, inplace = False)
Morgan_Stanley = Morgan_Stanley.rename(columns = {'Open': 'MS_Open', 'High': 'MS_High','Low': 'MS_Low','Close': 'MS','Adj Close': 'MS_Adj Close','Volume': 'MS_Volume'}, inplace = False)
Wells_Fargo = Wells_Fargo.rename(columns = {'Open': 'WFC_Open', 'High': 'WFC_High','Low': 'WFC_Low','Close': 'WFC','Adj Close': 'WFC_Adj Close','Volume': 'WFC_Volume'}, inplace = False)

Johnson_and_Johnson = Johnson_and_Johnson.rename(columns = {'Open': 'JNJ_Open', 'High': 'JNJ_High','Low': 'JNJ_Low','Close': 'JNJ','Adj Close': 'JNJ_Adj Close','Volume': 'JNJ_Volume'}, inplace = False)
Merck_and_CO = Merck_and_CO.rename(columns = {'Open': 'MRK_Open', 'High': 'MRK_High','Low': 'MRK_Low','Close': 'MRK','Adj Close': 'MRK_Adj Close','Volume': 'MRK_Volume'}, inplace = False)
Pfizer = Pfizer.rename(columns = {'Open': 'PFE_Open', 'High': 'PFE_High','Low': 'PFE_Low','Close': 'PFE','Adj Close': 'PFE_Adj Close','Volume': 'PFE_Volume'}, inplace = False)
UnitedHealthGroup = UnitedHealthGroup.rename(columns = {'Open': 'UNH_Open', 'High': 'UNH_High','Low': 'UNH_Low','Close': 'UNH','Adj Close': 'UNH_Adj Close','Volume': 'UNH_Volume'}, inplace = False)

Bausch_Health = Bausch_Health.rename(columns = {'Open': 'BHC_Open', 'High': 'BHC_High','Low': 'BHC_Low','Close': 'BHC','Adj Close': 'BHC_Adj Close','Volume': 'BHC_Volume'}, inplace = False)
Roche_Holding = Roche_Holding.rename(columns = {'Open': 'RHHBY_Open', 'High': 'RHHBY_High','Low': 'RHHBY_Low','Close': 'RHHBY','Adj Close': 'RHHBY_Adj Close','Volume': 'RHHBY_Volume'}, inplace = False)

Apple = Apple.rename(columns = {'Open': 'AAPL_Open', 'High': 'AAPL_High','Low': 'AAPL_Low','Close': 'AAPL','Adj Close': 'AAPL_Adj Close','Volume': 'AAPL_Volume'}, inplace = False)
Amazon = Amazon.rename(columns = {'Open': 'AMZN_Open', 'High': 'AMZN_High','Low': 'AMZN_Low','Close': 'AMZN','Adj Close': 'AMZN_Adj Close','Volume': 'AMZN_Volume'}, inplace = False)
Facebook = Facebook.rename(columns = {'Open': 'FB_Open', 'High': 'FB_High','Low': 'FB_Low','Close': 'FB','Adj Close': 'FB_Adj Close','Volume': 'FB_Volume'}, inplace = False)
Alphabet = Alphabet.rename(columns = {'Open': 'GOOG_Open', 'High': 'GOOG_High','Low': 'GOOG_Low','Close': 'GOOG','Adj Close': 'GOOG_Adj Close','Volume': 'GOOG_Volume'}, inplace = False)
IBM = IBM.rename(columns = {'Open': 'IBM_Open', 'High': 'IBM_High','Low': 'IBM_Low','Close': 'IBM','Adj Close': 'IBM_Adj Close','Volume': 'IBM_Volume'}, inplace = False)
Microsoft = Microsoft.rename(columns = {'Open': 'MSFT_Open', 'High': 'MSFT_High','Low': 'MSFT_Low','Close': 'MSFT','Adj Close': 'MSFT_Adj Close','Volume': 'MSFT_Volume'}, inplace = False)

SP500 = SP500.rename(columns = {'Open': 'S&P500_Open', 'High': 'S&P500_High','Low': 'S&P500_Low','Close': 'S&P500','Adj Close': 'S&P500_Adj Close','Volume': 'S&P500_Volume'}, inplace = False)

# %%
# here we are creating the new subsets from the data to do the further processing

# S&P500 index
SP500 = SP500[['Date','S&P500']]

# Aviation stocks
AAL = American_Airlines[['Date','AAL']]
ALGT = Allegiant_Travel[['Date','ALGT']]
ALK = Alaska_AirLk[['Date','ALK']]
DAL = Delta_AirLines[['Date','DAL']]
HA = Hawaiian_Holdings[['Date','HA']]
LUV = Southwest_Airlines[['Date','LUV']]

# Finance stocks
BCS = Barclays[['Date','BCS']]
CS = Credit_Suisse[['Date','CS']]
DB = Deutsche_Bank[['Date','DB']]
GS = Goldman_Sachs[['Date','GS']]
MS = Morgan_Stanley[['Date','MS']]
WFC = Wells_Fargo[['Date','WFC']]

# Pharma_healthcare stocks
BHC = Bausch_Health[['Date','BHC']]
JNJ = Johnson_and_Johnson[['Date','JNJ']]
MRK = Merck_and_CO[['Date','MRK']]
PFE = Pfizer[['Date','PFE']]
RHHBY = Roche_Holding[['Date','RHHBY']]
UNH = UnitedHealthGroup[['Date','UNH']]

# Technology stocks
AAPL = Apple[['Date','AAPL']]
AMZN = Amazon[['Date','AMZN']]
FB = Facebook[['Date','FB']]
GOOG = Alphabet[['Date','GOOG']]
IBM = IBM[['Date','IBM']]
MSFT = Microsoft[['Date','MSFT']]

# %%
# Lets merge the subsets of the data into a common dataset
data = pd.merge(SP500, AAL, how='inner', on='Date')
data = pd.merge(data, ALGT, how='inner', on='Date')
data = pd.merge(data, ALK, how='inner', on='Date')
data = pd.merge(data, DAL, how='inner', on='Date')
data = pd.merge(data, HA, how='inner', on='Date')
data = pd.merge(data, LUV, how='inner', on='Date')

data = pd.merge(data, BCS, how='inner', on='Date')
data = pd.merge(data, CS, how='inner', on='Date')
data = pd.merge(data, DB, how='inner', on='Date')
data = pd.merge(data, GS, how='inner', on='Date')
data = pd.merge(data, MS, how='inner', on='Date')
data = pd.merge(data, WFC, how='inner', on='Date')

data = pd.merge(data, BHC, how='inner', on='Date')
data = pd.merge(data, JNJ, how='inner', on='Date')
data = pd.merge(data, MRK, how='inner', on='Date')
data = pd.merge(data, PFE, how='inner', on='Date')
data = pd.merge(data, RHHBY, how='inner', on='Date')
data = pd.merge(data, UNH, how='inner', on='Date')

data = pd.merge(data, AAPL, how='inner', on='Date')
data = pd.merge(data, AMZN, how='inner', on='Date')
data = pd.merge(data, FB, how='inner', on='Date')
data = pd.merge(data, GOOG, how='inner', on='Date')
data = pd.merge(data, IBM, how='inner', on='Date')
data = pd.merge(data, MSFT, how='inner', on='Date')

# %%
#Lets check our complete dataset
data.head()
# Out:
#       Date       S&P500      AAL     ALGT        ALK      DAL    HA    LUV  \
# 0  18-05-2012  1295.219971  10.06  62.310001  16.170000  10.14  5.28  8.15
# 1  21-05-2012  1315.989990  10.71  62.660000  16.379999  10.58  5.32  8.34
# 2  22-05-2012  1316.630005  10.62  62.349998  16.225000  10.54  5.23  8.27
# 3  23-05-2012  1318.859985  11.00  62.990002  16.115000  10.74  5.38  8.36
# 4  24-05-2012  1320.680054  12.16  64.250000  16.920000  11.27  5.68  8.74
#
#       BCS        CS         DB         GS       MS       WFC        BHC     \
# 0  10.285714  19.169922  34.370228  95.489998  13.35  30.940001  47.029999
# 1  10.672812  19.541016  35.505726  96.510002  13.19  31.400000  47.189999
# 2  10.857142  19.863281  35.410305  97.529999  13.31  31.670000  47.779999
# 3  10.737328  19.765625  35.381680  98.040001  13.37  31.740000  46.650002
# 4  10.746544  19.658203  34.828243  96.860001  13.31  31.809999  48.040001
#
#       JNJ        MRK        PFE       RHHBY       UNH       AAPL     \
# 0  63.349998  37.820000  22.570000  20.160000  53.990002  18.942142
# 1  63.470001  37.599998  22.540001  20.389999  55.549999  20.045713
# 2  63.520000  37.459999  22.370001  20.430000  55.720001  19.891787
# 3  63.270000  37.340000  22.090000  20.075001  55.360001  20.377142
# 4  63.099998  37.599998  22.139999  19.855000  56.220001  20.190001
#
#       AMZN        FB         GOOG         IBM       MSFT
# 0  213.850006  38.230000  299.078979  195.880005  29.270000
# 1  218.110001  34.029999  305.908386  197.759995  29.750000
# 2  215.330002  31.000000  299.278229  196.820007  29.760000
# 3  217.279999  32.000000  303.592072  196.119995  29.110001
# 4  215.240005  33.029999  300.702881  196.089996  29.070000

# %% [markdown]
# **3.2 Inspect Dataframe**

# %%
#Lets check the database dimension
print("Database dimension     :",data.shape)
print("Number of Row          :",len(data.index))
print("Number of Columns      :",len(data.columns))
# Out:
# Database dimension     : (2106, 26)
# Number of Row          : 2106
# Number of Columns      : 26

# %%
#Lets check the numerical columns statistics
data.describe()
# Out:
#          S&P500         AAL         ALGT          ALK          DAL      \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean   2273.892283    33.552859   133.642911    56.696432    40.479141
# std     534.027978    13.036814    35.668011    20.649972    14.673069
# min    1278.040039     9.040000    62.259998    16.115000     8.550000
# 25%    1895.847473    22.792499   109.180000    38.462500    30.582500
# 50%    2132.765014    36.365000   136.060005    62.570002    45.315000
# 75%    2736.487549    43.465001   159.899994    69.169998    51.552501
# max    3580.840088    58.470001   233.979996   100.239998    63.160000
#
#            HA           LUV          BCS          CS           DB       \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean     26.177854    38.977840    11.822157    19.199134    23.418093
# std      14.808009    16.480813     3.736298     7.109165    13.237359
# min       5.220000     8.150000     3.840000     6.670000     5.480000
# 25%      13.132500    26.875001     8.892500    13.192500    11.220000
# 50%      25.920001    41.850001    10.940000    16.304296    18.740000
# 75%      38.437501    53.024999    15.387500    26.477500    34.647500
# max      60.299999    66.290001    19.580000    33.840000    51.898853
#
#            GS           MS           WFC          BHC          JNJ      \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean    188.979198    36.923936    47.520798    65.469117   113.375522
# std      38.409585    10.838003     8.998725    61.730865    23.369759
# min      91.000000    12.360000    22.530001     8.510000    61.779999
# 25%     162.255001    29.365001    43.627500    20.567500    97.940002
# 50%     189.885002    37.295000    49.770000    28.490000   114.684998
# 75%     219.892494    45.657500    54.097499   105.919998   132.887500
# max     273.380005    58.910000    65.930000   262.519989   155.509995
#
#            MRK          PFE         RHHBY         UNH         AAPL      \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean     61.404653    33.580147    32.943830   159.649582    37.230219
# std      12.786464     4.930604     4.905682    81.072224    20.480593
# min      37.180000    21.600000    19.430000    51.000000    13.947500
# 25%      52.980000    30.282501    30.526250    81.502500    23.573750
# 50%      58.965000    33.590000    32.514999   138.119995    30.137500
# 75%      68.764998    36.340000    35.700001   240.174996    45.233126
# max      92.040001    46.230000    46.840000   323.700012   134.179993
#
#           AMZN          FB          GOOG          IBM         MSFT
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean    984.016083   119.599425   816.281595   159.660071    76.196852
# std     749.076388    63.839134   337.218474    25.113899    47.698636
# min     208.220001    17.730000   278.481171    94.769997    26.370001
# 25%     331.909996    68.429998   536.690002   141.279999    41.272500
# 50%     743.445007   118.680000   759.674988   155.095001    56.494999
# 75%    1643.132507   173.980003  1101.962494   182.865005   104.955002
# max    3531.449951   303.910004  1728.280029   215.800003   231.649994

# %%
#Lets check the info about the column types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2106 entries, 0 to 2105
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2106 non-null   object
#  1   S&P500  2106 non-null   float64
#  2   AAL     2106 non-null   float64
#  3   ALGT    2106 non-null   float64
#  4   ALK     2106 non-null   float64
#  5   DAL     2106 non-null   float64
#  6   HA      2106 non-null   float64
#  7   LUV     2106 non-null   float64
#  8   BCS     2106 non-null   float64
#  9   CS      2106 non-null   float64
#  10  DB      2106 non-null   float64
#  11  GS      2106 non-null   float64
#  12  MS      2106 non-null   float64
#  13  WFC     2106 non-null   float64
#  14  BHC     2106 non-null   float64
#  15  JNJ     2106 non-null   float64
#  16  MRK     2106 non-null   float64
#  17  PFE     2106 non-null   float64
#  18  RHHBY   2106 non-null   float64
#  19  UNH     2106 non-null   float64
#  20  AAPL    2106 non-null   float64
#  21  AMZN    2106 non-null   float64
#  22  FB      2106 non-null   float64
#  23  GOOG    2106 non-null   float64
#  24  IBM     2106 non-null   float64
#  25  MSFT    2106 non-null   float64
# dtypes: float64(25), object(1)
# memory usage: 444.2+ KB

# %% [markdown]
# **3.3 Data Cleaning**

# %%
#display data types of the column in dataframe ad
data.dtypes
# Out:
# Date       object
# S&P500    float64
# AAL       float64
# ALGT      float64
# ALK       float64
# DAL       float64
# HA        float64
# LUV       float64
# BCS       float64
# CS        float64
# DB        float64
# GS        float64
# MS        float64
# WFC       float64
# BHC       float64
# JNJ       float64
# MRK       float64
# PFE       float64
# RHHBY     float64
# UNH       float64
# AAPL      float64
# AMZN      float64
# FB        float64
# GOOG      float64
# IBM       float64
# MSFT      float64
# dtype: object

# %% [markdown]
# As we can see that the date datatype is object, we need to change it to date format

# %%
# lets change the date column to datetime format
data["Date"]= pd.to_datetime(data["Date"], format='%d-%m-%Y')

#display data types of the column in dataframe ad
data.dtypes
# Out:
# Date      datetime64[ns]
# S&P500           float64
# AAL              float64
# ALGT             float64
# ALK              float64
# DAL              float64
# HA               float64
# LUV              float64
# BCS              float64
# CS               float64
# DB               float64
# GS               float64
# MS               float64
# WFC              float64
# BHC              float64
# JNJ              float64
# MRK              float64
# PFE              float64
# RHHBY            float64
# UNH              float64
# AAPL             float64
# AMZN             float64
# FB               float64
# GOOG             float64
# IBM              float64
# MSFT             float64
# dtype: object

# %%
#lets convert the datecolumn as index for our reference
data = data.set_index('Date')

#lets check the data columnn
data.head()
# Out:
#               S&P500      AAL     ALGT        ALK      DAL    HA    LUV  \
# Date
# 2012-05-18  1295.219971  10.06  62.310001  16.170000  10.14  5.28  8.15
# 2012-05-21  1315.989990  10.71  62.660000  16.379999  10.58  5.32  8.34
# 2012-05-22  1316.630005  10.62  62.349998  16.225000  10.54  5.23  8.27
# 2012-05-23  1318.859985  11.00  62.990002  16.115000  10.74  5.38  8.36
# 2012-05-24  1320.680054  12.16  64.250000  16.920000  11.27  5.68  8.74
#
#                BCS        CS         DB         GS       MS       WFC     \
# Date
# 2012-05-18  10.285714  19.169922  34.370228  95.489998  13.35  30.940001
# 2012-05-21  10.672812  19.541016  35.505726  96.510002  13.19  31.400000
# 2012-05-22  10.857142  19.863281  35.410305  97.529999  13.31  31.670000
# 2012-05-23  10.737328  19.765625  35.381680  98.040001  13.37  31.740000
# 2012-05-24  10.746544  19.658203  34.828243  96.860001  13.31  31.809999
#
#                BHC        JNJ        MRK        PFE       RHHBY       UNH     \
# Date
# 2012-05-18  47.029999  63.349998  37.820000  22.570000  20.160000  53.990002
# 2012-05-21  47.189999  63.470001  37.599998  22.540001  20.389999  55.549999
# 2012-05-22  47.779999  63.520000  37.459999  22.370001  20.430000  55.720001
# 2012-05-23  46.650002  63.270000  37.340000  22.090000  20.075001  55.360001
# 2012-05-24  48.040001  63.099998  37.599998  22.139999  19.855000  56.220001
#
#               AAPL        AMZN        FB         GOOG         IBM     \
# Date
# 2012-05-18  18.942142  213.850006  38.230000  299.078979  195.880005
# 2012-05-21  20.045713  218.110001  34.029999  305.908386  197.759995
# 2012-05-22  19.891787  215.330002  31.000000  299.278229  196.820007
# 2012-05-23  20.377142  217.279999  32.000000  303.592072  196.119995
# 2012-05-24  20.190001  215.240005  33.029999  300.702881  196.089996
#
#               MSFT
# Date
# 2012-05-18  29.270000
# 2012-05-21  29.750000
# 2012-05-22  29.760000
# 2012-05-23  29.110001
# 2012-05-24  29.070000

# %%
# here we need to analyse the data for last 5 years and predict for next 5 years
# i.e. as the client is looking for an investment period of 5 years
data = data['10-01-2015':]
data.head()
# Out:
#               S&P500        AAL        ALGT        ALK        DAL     \
# Date
# 2015-10-01  1923.819946  39.200001  217.979996  80.230003  45.410000
# 2015-10-02  1951.359985  38.630001  215.589996  79.260002  44.869999
# 2015-10-05  1987.050049  40.189999  216.059998  80.910004  46.959999
# 2015-10-06  1979.920044  38.130001  208.600006  74.529999  45.090000
# 2015-10-07  1995.829956  39.310001  213.839996  75.970001  45.990002
#
#                HA         LUV      BCS      CS         DB          GS      \
# Date
# 2015-10-01  24.730000  38.410000  15.01  24.090000  26.520000  176.020004
# 2015-10-02  24.280001  38.380001  15.39  24.639999  27.139999  177.009995
# 2015-10-05  25.500000  39.299999  15.60  25.160000  28.200001  180.699997
# 2015-10-06  24.250000  38.000000  15.55  25.379999  28.400000  180.320007
# 2015-10-07  24.559999  38.709999  15.73  25.320000  28.790001  182.229996
#
#                MS         WFC         BHC        JNJ        MRK        PFE     \
# Date
# 2015-10-01  31.500000  51.439999  179.600006  93.169998  49.369999  31.840000
# 2015-10-02  31.430000  51.259998  182.320007  93.930000  50.139999  33.080002
# 2015-10-05  32.290001  52.410000  163.460007  94.760002  51.230000  33.480000
# 2015-10-06  32.360001  52.029999  166.000000  93.419998  49.799999  32.790001
# 2015-10-07  32.930000  52.189999  169.830002  94.980003  50.950001  33.290001
#
#               RHHBY        UNH       AAPL        AMZN        FB      \
# Date
# 2015-10-01  33.220001  116.610001  27.395000  520.719971  90.949997
# 2015-10-02  33.320000  118.830002  27.594999  532.539978  92.070000
# 2015-10-05  33.439999  119.650002  27.695000  543.679993  94.010002
# 2015-10-06  33.529999  116.050003  27.827499  537.479980  92.800003
# 2015-10-07  32.549999  116.430000  27.695000  541.940002  92.400002
#
#                GOOG         IBM       MSFT
# Date
# 2015-10-01  611.289978  143.589996  44.610001
# 2015-10-02  626.909973  144.580002  45.570000
# 2015-10-05  641.469971  149.039993  46.630001
# 2015-10-06  645.440002  148.779999  46.750000
# 2015-10-07  642.359985  150.089996  46.799999

# %% [markdown]
# **3.4 Null Value Calculation**

# %%
data.isnull().sum()
# Out:
# S&P500    0
# AAL       0
# ALGT      0
# ALK       0
# DAL       0
# HA        0
# LUV       0
# BCS       0
# CS        0
# DB        0
# GS        0
# MS        0
# WFC       0
# BHC       0
# JNJ       0
# MRK       0
# PFE       0
# RHHBY     0
# UNH       0
# AAPL      0
# AMZN      0
# FB        0
# GOOG      0
# IBM       0
# MSFT      0
# dtype: int64

# %% [markdown]
# **3.4.1 Column wise Null Value calculation**

# %%
#Column wise null values in train data set
null_perc = pd.DataFrame(round((data.isnull().sum())*100/data.shape[0],2)).reset_index()
null_perc.columns = ['Column Name', 'Null Values Percentage']
null_value = pd.DataFrame(data.isnull().sum()).reset_index()
null_value.columns = ['Column Name', 'Null Values']
null_data = pd.merge(null_value, null_perc, on='Column Name')
null_data.sort_values("Null Values", ascending = False)
# Out:
#    Column Name  Null Values  Null Values Percentage
# 0     S&P500         0                 0.0
# 13       BHC         0                 0.0
# 23       IBM         0                 0.0
# 22      GOOG         0                 0.0
# 21        FB         0                 0.0
# 20      AMZN         0                 0.0
# 19      AAPL         0                 0.0
# 18       UNH         0                 0.0
# 17     RHHBY         0                 0.0
# 16       PFE         0                 0.0
# 15       MRK         0                 0.0
# 14       JNJ         0                 0.0
# 12       WFC         0                 0.0
# 1        AAL         0                 0.0
# 11        MS         0                 0.0
# 10        GS         0                 0.0
# 9         DB         0                 0.0
# 8         CS         0                 0.0
# 7        BCS         0                 0.0
# 6        LUV         0                 0.0
# 5         HA         0                 0.0
# 4        DAL         0                 0.0
# 3        ALK         0                 0.0
# 2       ALGT         0                 0.0
# 24      MSFT         0                 0.0

# %% [markdown]
# **3.4.2 Row wise Null Value calculation**

# %%
Row_Null40_Count = len(data[data.isnull().sum(axis=1)/data.shape[1]>0.40])
print( 'Total number of rows with more than 40% null values are : ', Row_Null40_Count)
# Out:
# Total number of rows with more than 40% null values are :  0

# %%
#Lets export the cleaned dataset in CSV format
data.to_csv(normal_path+'Final_Cleaned_Dataset.csv')
